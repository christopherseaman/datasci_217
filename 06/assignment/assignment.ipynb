# %% [markdown]
# # Assignment 06: Merge, Stack, and Reshape Clinic Data
#
# `README.md` gives each task's steps and checkpoints; the headings here match its numbering. Run each cell with `Shift+Enter`. When you finish, click **Restart**, then **Run All**, and run `python check_assignment.py` in the terminal.

# %%
from pathlib import Path

import pandas as pd

print("pandas:", pd.__version__)

DATA_DIR = Path("data")
OUTPUT_DIR = Path("output")
OUTPUT_DIR.mkdir(exist_ok=True)

MERGE_AUDIT_PATH = OUTPUT_DIR / "specimen_merge_audit.csv"
COMBINED_PATH = OUTPUT_DIR / "combined_specimens.csv"
ALIGNED_PATH = OUTPUT_DIR / "aligned_features.csv"
SBP_LONG_PATH = OUTPUT_DIR / "sbp_long.csv"
SBP_ROUND_TRIP_PATH = OUTPUT_DIR / "sbp_round_trip.csv"

print("data folder found:", DATA_DIR.exists())

# %% [markdown]
# ## Load the data
#
# This cell reads the six supplied files. Run it as it is.

# %%
specimens = pd.read_csv(DATA_DIR / "specimens.csv")
clinics_history = pd.read_csv(DATA_DIR / "clinics_history.csv")
batch_a = pd.read_csv(DATA_DIR / "specimens_batch_a.csv")
batch_b = pd.read_csv(DATA_DIR / "specimens_batch_b.csv")
transit_times = pd.read_csv(DATA_DIR / "transit_times.csv")
sbp_wide = pd.read_csv(DATA_DIR / "sbp_wide.csv")

print("specimens:", specimens.shape)
print("clinics_history:", clinics_history.shape)
print("batch_a:", batch_a.shape, " batch_b:", batch_b.shape)
print("transit_times:", transit_times.shape)
print("sbp_wide:", sbp_wide.shape)
clinics_history

# %% [markdown]
# ## Task 1: Merge specimens with their clinics
#
# ### 1.1 Find the repeated clinic key

# %%
specimen_ids_unique = None  # TODO: True when no specimen_id repeats in specimens
print("specimen_id unique:", specimen_ids_unique)

repeated_clinic_rows = None  # TODO: every clinics_history row whose clinic_id appears more than once
repeated_clinic_rows

# %%
# TODO: in a try block, left-merge specimens with clinics_history on clinic_id with validate="many_to_one".
# TODO: in the except block, catch pd.errors.MergeError and print it.

# %% [markdown]
# ### 1.2 Keep the current records, merge, and save
#
# > **Checkpoint: `output/specimen_merge_audit.csv`**
# > Seven rows under the header `specimen_id,patient_id,collection_number,clinic_id,specimen_type,volume_ml,clinic_name,region,_merge`.

# %%
current_clinics = None  # TODO: the clinics_history rows whose record_status is "current", with the columns clinic_id, clinic_name, region
print("current clinic_id unique:", current_clinics["clinic_id"].is_unique)

merge_audit = None  # TODO: left-merge specimens with current_clinics on clinic_id, with validate="many_to_one" and indicator=True
print("rows:", len(merge_audit))
print(merge_audit["_merge"].value_counts())

# TODO: save merge_audit to MERGE_AUDIT_PATH without the row index

merge_audit

# %% [markdown]
# ## Task 2: Stack the batches and line up features
#
# ### 2.1 Stack the two batches
#
# > **Checkpoint: `output/combined_specimens.csv`**
# > Seven rows under the header `specimen_id,patient_id,collection_number,clinic_id,specimen_type,volume_ml,source_partition`.

# %%
# TODO: add a source_partition column to each batch: "batch_a" on every batch_a row, "batch_b" on every batch_b row

combined_specimens = None  # TODO: batch_a stacked above batch_b with pd.concat, numbered 0 to 6 with ignore_index=True
print("rows:", len(combined_specimens))
print("same specimens as specimens.csv:", combined_specimens.drop(columns="source_partition").equals(specimens))

# TODO: save combined_specimens to COMBINED_PATH without the row index

combined_specimens

# %% [markdown]
# ### 2.2 Stack batches whose columns differ
#
# This step saves nothing; it shows what `pd.concat()` does when the columns differ.

# %%
batch_b_changed = None  # TODO: batch_b without its volume_ml column
# TODO: add a courier_note column to batch_b_changed holding "late pickup" on every row

drift_preview = None  # TODO: batch_a stacked above batch_b_changed with pd.concat and ignore_index=True
print(drift_preview.isna().sum())
drift_preview

# %% [markdown]
# ### 2.3 Line up volumes and transit times
#
# > **Checkpoint: `output/aligned_features.csv`**
# > Five rows, `SP101` to `SP104` and `SP108`, under the header `specimen_id,volume_ml,transit_min`.

# %%
volumes = None  # TODO: batch_a's specimen_id and volume_ml columns, with specimen_id moved into the index
transit = None  # TODO: transit_times with specimen_id moved into the index
print("volume labels unique:", volumes.index.is_unique)
print("transit labels unique:", transit.index.is_unique)

aligned_features = None  # TODO: volumes and transit side by side with pd.concat(..., axis=1)

# TODO: save aligned_features to ALIGNED_PATH, keeping its specimen_id index

aligned_features

# %% [markdown]
# ## Task 3: Reshape the blood pressure readings
#
# ### 3.1 Melt wide to long
#
# > **Checkpoint: `output/sbp_long.csv`**
# > Eight rows under the header `patient_id,visit,sbp`.

# %%
sbp_long = None  # TODO: melt sbp_wide: id_vars patient_id, value_vars baseline and followup, var_name "visit", value_name "sbp"
print("rows:", len(sbp_long))
print("repeated patient-visit pairs:", sbp_long.duplicated(subset=["patient_id", "visit"]).sum())

# TODO: save sbp_long to SBP_LONG_PATH without the row index

sbp_long

# %% [markdown]
# ### 3.2 Pivot back to wide
#
# > **Checkpoint: `output/sbp_round_trip.csv`**
# > Four rows, `P201` to `P204`, under the header `patient_id,baseline,followup`.

# %%
sbp_round_trip = None  # TODO: pivot sbp_long with index "patient_id", columns "visit", values "sbp", then reset_index()
# TODO: drop the leftover "visit" header label: sbp_round_trip.columns.name = None
print("round trip matches sbp_wide:", sbp_round_trip.equals(sbp_wide))

# TODO: save sbp_round_trip to SBP_ROUND_TRIP_PATH without the row index

sbp_round_trip

# %% [markdown]
# ### 3.3 Find the pair that stops `pivot()`
#
# P202's follow-up blood pressure was rechecked, so the next cell adds a second follow-up reading for P202. This step saves nothing.

# %%
recheck = pd.DataFrame({"patient_id": ["P202"], "visit": ["followup"], "sbp": [147]})
sbp_rechecked = pd.concat([sbp_long, recheck], ignore_index=True)

repeated_pairs = None  # TODO: every sbp_rechecked row whose patient_id and visit pair appears more than once
display(repeated_pairs)

# TODO: in a try block, pivot sbp_rechecked as in 3.2 (index "patient_id", columns "visit", values "sbp").
# TODO: in the except block, catch ValueError and print it.

# %% [markdown]
# ## Fresh-run check
#
# Click **Restart**, then **Run All**. This cell checks the notebook's own results; `python check_assignment.py` checks the five saved files.

# %%
assert specimen_ids_unique, "Task 1.1: specimen_id should be unique in specimens"
assert len(repeated_clinic_rows) == 2, "Task 1.1: K01 has two rows in clinics_history"
assert len(merge_audit) == len(specimens), "Task 1.2: the left merge should keep one row per specimen"
assert combined_specimens.drop(columns="source_partition").equals(specimens), (
    "Task 2.1: stacking batch_a above batch_b should rebuild specimens.csv"
)
assert drift_preview["volume_ml"].isna().sum() == 3, "Task 2.2: batch_b_changed's three rows have no volume_ml"
assert sorted(aligned_features.index) == ["SP101", "SP102", "SP103", "SP104", "SP108"], (
    "Task 2.3: aligned_features should keep every specimen_id label from both tables"
)
assert len(sbp_long) == 8, "Task 3.1: four patients times two visits is eight rows"
assert sbp_round_trip.equals(sbp_wide), "Task 3.2: the round trip should rebuild sbp_wide"
assert len(repeated_pairs) == 2, "Task 3.3: P202's two follow-up rows"
for path in [MERGE_AUDIT_PATH, COMBINED_PATH, ALIGNED_PATH, SBP_LONG_PATH, SBP_ROUND_TRIP_PATH]:
    assert path.exists(), f"{path} is missing; run the cell that saves it"

print("Fresh-run check passed")
