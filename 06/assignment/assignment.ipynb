# %% [markdown]
# # Assignment 06: Validated Combination and Structural Reshaping
#
# Work in **local Jupyter** with CPython 3.12.13, NumPy 2.0.2, and pandas 3.0.3. These small course-authored fixtures are synthetic and contain no human-subject data.
#
# Complete every `TODO`, restart the kernel, and run all 25 cells in order. Your notebook must write these exact tracked artifacts: `specimen_merge_audit.csv`, `combined_specimens.csv`, `aligned_features.csv`, `sensor_scores_long.csv`, and `sensor_scores_round_trip.csv` in `output/`. Then run `python check_assignment.py` from the assignment directory.
#
# You will declare grain, keys, cardinality, and preservation intent; diagnose and repair a merge contract; compare vertical and horizontal alignment; and complete a reversible nonaggregating reshape.

# %%
from hashlib import sha256
import json
from pathlib import Path

import numpy as np
import pandas as pd

EXPECTED_FIXTURE_SET_ID = 'a06-structural-wrangling-v1'
REQUIRED_FIXTURE_FILES = {
    'specimens.csv',
    'stations_history.csv',
    'specimens_batch_a.csv',
    'specimens_batch_b.csv',
    'review_scores.csv',
    'sensor_scores_wide.csv',
}
EXPECTED_ARTIFACT_SHA256 = {
    'specimen_merge_audit.csv': '1bc33aeecbae2483e314399784bbcaf8b8847798fe3ca5b7662908053615e98c',
    'combined_specimens.csv': '78cbd883bea393fb84d699cdb9923a9d71d7c045d002eebe88cc84c9da61c666',
    'aligned_features.csv': '19cb5d07f7ae51ce0347876802a44eadf48490076bb24dbdcae547d9388775e7',
    'sensor_scores_long.csv': '989affb14d49ecd0e144e23a6b53ab4a093edd6211656390144869ecaa3126dd',
    'sensor_scores_round_trip.csv': '6eb9bfb9561fc7c55708bc0038b77b99e6d383f85843dff3e735c5962abe8701',
}

def _find_manifest():
    start = Path.cwd().resolve()
    for parent in (start, *start.parents):
        for relative in (Path('data/fixture.json'), Path('06/assignment/data/fixture.json')):
            candidate = parent / relative
            if candidate.is_file():
                return candidate.resolve()
    raise FileNotFoundError(
        'Could not find data/fixture.json or 06/assignment/data/fixture.json above the working directory.'
    )

MANIFEST_PATH = _find_manifest()
ASSIGNMENT_ROOT = MANIFEST_PATH.parent.parent
DATA_DIR = MANIFEST_PATH.parent
OUTPUT_DIR = ASSIGNMENT_ROOT / 'output'

with MANIFEST_PATH.open(encoding='utf-8') as stream:
    fixture_manifest = json.load(stream)
if set(fixture_manifest) != {'fixture_set_id', 'provenance', 'files'}:
    raise ValueError('Fixture manifest fields changed; restore data/fixture.json.')
if fixture_manifest['fixture_set_id'] != EXPECTED_FIXTURE_SET_ID:
    raise ValueError('Unexpected fixture set; restore the Assignment 06 data directory.')
if not isinstance(fixture_manifest['provenance'], str) or not fixture_manifest['provenance'].strip():
    raise ValueError('Fixture provenance must be a nonempty string.')
records = fixture_manifest['files']
if not isinstance(records, list) or len(records) != 6:
    raise ValueError('Fixture manifest must describe exactly six CSV files.')
manifest_names = []
for record in records:
    if set(record) != {'path', 'row_grain', 'row_count', 'columns', 'sha256'}:
        raise ValueError('A fixture manifest record has unexpected fields.')
    relative = Path(record['path'])
    if relative.name != record['path'] or relative.suffix != '.csv':
        raise ValueError(f'Unsafe fixture path: {record["path"]!r}')
    fixture_path = (DATA_DIR / relative).resolve()
    if fixture_path.parent != DATA_DIR.resolve():
        raise ValueError(f'Fixture path escapes data directory: {record["path"]!r}')
    if not fixture_path.is_file():
        raise FileNotFoundError(f'Missing fixture: {fixture_path.name}')
    if sha256(fixture_path.read_bytes()).hexdigest() != record['sha256']:
        raise ValueError(f'Checksum mismatch for {fixture_path.name}; restore the supplied file.')
    if not isinstance(record['row_grain'], str) or not record['row_grain'].strip():
        raise ValueError(f'Invalid row grain for {fixture_path.name}.')
    if not isinstance(record['row_count'], int) or record['row_count'] < 1:
        raise ValueError(f'Invalid row count for {fixture_path.name}.')
    if not isinstance(record['columns'], list) or not all(isinstance(value, str) for value in record['columns']):
        raise ValueError(f'Invalid columns for {fixture_path.name}.')
    manifest_names.append(record['path'])
if set(manifest_names) != REQUIRED_FIXTURE_FILES or len(manifest_names) != len(set(manifest_names)):
    raise ValueError('Fixture manifest inventory changed; restore the supplied manifest.')
actual_names = {path.name for path in DATA_DIR.glob('*.csv') if path.is_file()}
if actual_names != REQUIRED_FIXTURE_FILES:
    raise ValueError('Fixture CSV inventory changed; restore the supplied data directory.')

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
ARTIFACT_PATHS = {name: OUTPUT_DIR / name for name in EXPECTED_ARTIFACT_SHA256}
pd.set_option('display.max_columns', 20)
print(f'Assignment root: {ASSIGNMENT_ROOT} | verified fixture: {EXPECTED_FIXTURE_SET_ID}')

# %% [markdown]
# ## Data contract
#
# **Grain** states what one row represents; a **key** is the column set that uniquely identifies a row at that grain. `specimens.csv` has one row per specimen, primary key `specimen_id`, candidate key (`collector_id`, `collection_number`), and foreign key `station_code`. `stations_history.csv` has one row per station-history record, so `station_code` is not unique until you apply the supplied source rule `record_status == "current"`.
#
# The two batch files are row partitions at specimen grain. `review_scores.csv` has one row per reviewed specimen. `sensor_scores_wide.csv` has one row per (`sensor_id`, `station_code`) pair and two measurement columns.
#
# Do not invent a deduplication rule or clean structural missingness. State cardinality and preservation intent before combining tables, and make unmatched or duplicate keys visible.

# %%
# TODO: read all six fixtures with the explicit dtypes in the assignment contract.
specimens = None
stations_history = None
batch_a = None
batch_b = None
review_scores = None
sensor_scores_wide = None

# TODO: assert each exact shape and ordered column list before continuing.

# %% [markdown]
# ## Task 1 — contract-first validated merge
#
# **TODO:** In your own words, state the specimen and station-history row grains, the intended station grain after current-record selection, the primary/candidate/foreign keys, predicted cardinality, preservation goal, join choice, and what an unmatched foreign key should look like in the result.

# %%
# TODO: replace each placeholder with the exact machine-checkable contract value.
specimen_grain = None
station_history_grain = None
primary_key = None
candidate_key = None
foreign_key = None
predicted_cardinality = None
preservation_goal = None
join_type = None
predicted_rows = None

# %%
# TODO: assert nonmissing, unique specimen primary and candidate keys.
# TODO: select every station-history row whose station_code participates in a duplicate set.
duplicated_station_rows = None

# %%
duplicate_contract_failed = False
duplicate_error_name = None
# TODO: inside try/except, attempt the explicit-key left merge against unfiltered history.
# Use validate='many_to_one', catch only pd.errors.MergeError, and record the natural failure.

# %%
def select_current_stations(history_table):
    """Return the validated current station lookup without mutating the input."""
    # TODO
    pass


def validated_station_merge(specimen_table, station_table):
    """Return an explicit, validated, diagnostic specimen-to-station merge."""
    # TODO
    pass

# %%
# TODO: select current stations, recheck the lookup key, and run the validated merge.
current_stations = None
specimen_merge_audit = None
# TODO: assert exact columns, preserved IDs, indicator counts, the SP106/X orphan, and no U row.

# %%
# TODO: write specimen_merge_audit.csv with index=False and lineterminator='\n'.
# Read it back with explicit dtypes, normalize _merge to string, and compare exact frames.
specimen_merge_round_trip = None

# %% [markdown]
# ## Task 2 — vertical concatenation and horizontal alignment
#
# **TODO:** Before running the task, state the batch row grain, why batches A and B may be stacked, the predicted row count, and what provenance must record. Distinguish row stacking from index-aligned feature columns. Predict why concatenating different column labels will create structural missingness; reserve the post-observation explanation for the final reflection.

# %%
def stack_specimen_partitions(partition_map):
    """Stack copied specimen partitions with ordinary-column provenance."""
    # TODO
    pass

# %%
# TODO: stack the two canonical partitions with labels batch_a and batch_b.
combined_specimens = None
# TODO: assert row count, source counts, specimen order, RangeIndex, and base-column equality.

# %%
# TODO: make disposable batch copies; omit mass_g and add string review_note only in batch B.
schema_drift_preview = None
# TODO: assert three missing mass_g values and four missing review_note values. Do not clean or save.

# %%
def align_specimen_features(mass_table, review_table):
    """Outer-align mass and review features by a validated named specimen index."""
    # TODO
    pass

# %%
# TODO: align mass for SP101-SP103 with all review_scores.
aligned_features = None
# TODO: assert exact index order, missing positions, and the SP102/SP103 overlapping values.

# %%
# TODO: write combined_specimens.csv without an index and aligned_features.csv with its named index.
# Read both with explicit dtypes and compare exact frames including index name and order.
combined_round_trip = None
aligned_round_trip = None

# %% [markdown]
# ## Task 3 — nonaggregating wide/long reshape
#
# **TODO:** State the wide and long row grains, the two-column wide key, the three-column long key, and the predicted eight-row long result. Explain why each long key must identify exactly one value for structural `pivot` to be reversible.

# %%
def wide_to_long_scores(wide_table):
    """Melt a validated wide sensor table to its structural long form."""
    # TODO
    pass


def long_to_wide_scores(long_table, ordered_columns):
    """Pivot a uniquely keyed long table and restore caller-supplied order."""
    # TODO
    pass

# %%
# TODO: create the canonical long table and exact wide round-trip.
sensor_scores_long = None
sensor_scores_round_trip = None
# TODO: assert shape, columns, unique long key, label counts, and exact frame equality.

# %%
# TODO: append the first long row on a disposable table and select the full duplicate-key set.
duplicate_long_rows = None
duplicate_pivot_failed = False
# TODO: call long_to_wide_scores inside try/except and catch the natural ValueError from pivot.

# %%
# TODO: write sensor_scores_long.csv and sensor_scores_round_trip.csv without indexes.
# Read both with explicit dtypes and compare exact frames.
long_round_trip = None
wide_round_trip = None

# %% [markdown]
# ## Final reflection
#
# **TODO:** Answer concisely in your own words:
#
# 1. Why is the current-record source rule evidence-based while arbitrary deduplication is not?
# 2. How did the left merge implement the preservation goal and expose the orphan?
# 3. After observing both, why did vertical schema drift and horizontal label mismatch create different structural missingness?
# 4. Why do duplicate long keys make structural pivot ambiguous, and why is aggregation deferred?

# %%
assert specimen_grain == 'one row per specimen'
assert station_history_grain == 'one row per station-history record'
assert primary_key == ['specimen_id']
assert candidate_key == ['collector_id', 'collection_number']
assert foreign_key == ['station_code']
assert predicted_cardinality == 'many_to_one'
assert preservation_goal == 'keep every specimen row'
assert join_type == 'left' and predicted_rows == 7
assert duplicate_contract_failed is True and duplicate_error_name == 'MergeError'
assert duplicated_station_rows['station_code'].tolist() == ['R', 'R']
assert current_stations['station_code'].tolist() == ['R', 'S', 'T', 'U']
assert specimen_merge_audit['specimen_id'].tolist() == specimens['specimen_id'].tolist()
merge_counts = specimen_merge_audit['_merge'].astype('string').value_counts().reindex(
    ['both', 'left_only', 'right_only'], fill_value=0
).astype('int64').to_dict()
assert merge_counts == {'both': 6, 'left_only': 1, 'right_only': 0}
assert combined_specimens['specimen_id'].tolist() == specimens['specimen_id'].tolist()
assert combined_specimens['source_partition'].tolist() == ['batch_a'] * 4 + ['batch_b'] * 3
assert aligned_features.index.tolist() == ['SP101', 'SP102', 'SP103', 'SP108']
assert sensor_scores_long.shape == (8, 4)
assert duplicate_pivot_failed is True and len(duplicate_long_rows) == 2
pd.testing.assert_frame_equal(sensor_scores_round_trip, sensor_scores_wide)
for artifact_name, expected_digest in EXPECTED_ARTIFACT_SHA256.items():
    artifact_path = ARTIFACT_PATHS[artifact_name]
    assert artifact_path.is_file(), f'Missing output/{artifact_name}'
    assert sha256(artifact_path.read_bytes()).hexdigest() == expected_digest, f'Unexpected bytes in output/{artifact_name}'
print('Assignment 06 fresh-run verification passed. Restart the kernel, run all cells, then run: python check_assignment.py')
