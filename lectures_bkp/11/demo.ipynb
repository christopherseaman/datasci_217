# %% [markdown]
# ### Loading your API keys using .env
# #### Example .env:
# ```python
# REDCAP_API_URL='https://redcap.ucsf.edu/api/'
# REDCAP_API_KEY='YOUR_API_KEY'
# ```

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_url = os.environ['REDCAP_API_URL']
api_key = os.environ['REDCAP_API_KEY']

# %% [markdown]
# ### Import the REDCap project data

# %%
from redcap import Project # This is actually PyCap, which is annoyingly named.

# Import the REDCap project using your API Key
redcap_project = Project(api_url, api_key)
# Get the data from all the records in the project
redcap_data = redcap_project.export_records()
redcap_data
# Out:
# [{'patient_id': '23',
#   'birth_date': '1941-02-14',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-11-29',
#   'visit_age': '70',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '53',
#   'birth_date': '1930-04-12',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-01-25',
#   'visit_age': '81',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '70',
#   'birth_date': '1942-04-26',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '87',
#   'birth_date': '1933-05-09',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-12-22',
#   'visit_age': '89',
#   'mmse_tot': '18',
#   'main_complete': '0'},
#  {'patient_id': '97',
#   'birth_date': '1945-02-12',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-10-31',
#   'visit_age': '72',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '101',
#   'birth_date': '1940-06-14',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-12-16',
#   'visit_age': '78',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '102',
#   'birth_date': '1932-06-16',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-07-13',
#   'visit_age': '90',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '106',
#   'birth_date': '1937-01-09',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-04-09',
#   'visit_age': '65',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '114',
#   'birth_date': '1931-05-18',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-06-27',
#   'visit_age': '82',
#   'mmse_tot': '3',
#   'main_complete': '0'},
#  {'patient_id': '115',
#   'birth_date': '1939-11-12',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '2011-04-25',
#   'death_age': '71',
#   'visit_date': '2008-07-23',
#   'visit_age': '68',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '124',
#   'birth_date': '1931-05-08',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2000-09-06',
#   'visit_age': '69',
#   'mmse_tot': '24',
#   'main_complete': '0'},
#  {'patient_id': '127',
#   'birth_date': '1940-05-04',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '134',
#   'birth_date': '1952-04-25',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '135',
#   'birth_date': '1932-06-30',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-07-29',
#   'visit_age': '72',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '149',
#   'birth_date': '1953-12-03',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2016-08-31',
#   'visit_age': '62',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '151',
#   'birth_date': '1930-05-06',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-05-05',
#   'visit_age': '78',
#   'mmse_tot': '3',
#   'main_complete': '0'},
#  {'patient_id': '158',
#   'birth_date': '1931-06-12',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-12-06',
#   'visit_age': '82',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '161',
#   'birth_date': '1950-03-15',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-07-17',
#   'visit_age': '52',
#   'mmse_tot': '30',
#   'main_complete': '0'},
#  {'patient_id': '182',
#   'birth_date': '1947-07-15',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '2020-02-07',
#   'death_age': '72',
#   'visit_date': '2019-03-14',
#   'visit_age': '71',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '186',
#   'birth_date': '1932-02-22',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2014-04-17',
#   'visit_age': '82',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '195',
#   'birth_date': '1933-07-18',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-01-01',
#   'visit_age': '87',
#   'mmse_tot': '24',
#   'main_complete': '0'},
#  {'patient_id': '219',
#   'birth_date': '1932-08-31',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-04-19',
#   'visit_age': '84',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '226',
#   'birth_date': '1936-05-16',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '2023-10-19',
#   'death_age': '87',
#   'visit_date': '2022-04-15',
#   'visit_age': '85',
#   'mmse_tot': '1',
#   'main_complete': '0'},
#  {'patient_id': '250',
#   'birth_date': '',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '2023-09-01',
#   'death_age': '',
#   'visit_date': '2002-09-15',
#   'visit_age': '',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '253',
#   'birth_date': '1945-01-11',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2003-03-06',
#   'visit_age': '58',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '265',
#   'birth_date': '1943-12-31',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-12-30',
#   'visit_age': '78',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '267',
#   'birth_date': '1937-07-10',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-08-15',
#   'visit_age': '78',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '270',
#   'birth_date': '1933-01-06',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2005-04-06',
#   'visit_age': '72',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '274',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-12-11',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '278',
#   'birth_date': '1938-06-11',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-06-28',
#   'visit_age': '63',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '295',
#   'birth_date': '1937-12-23',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-10-03',
#   'visit_age': '85',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '300',
#   'birth_date': '1940-06-21',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-02-11',
#   'visit_age': '72',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '313',
#   'birth_date': '1933-11-30',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-05-06',
#   'visit_age': '75',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '342',
#   'birth_date': '1964-02-06',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '2024-01-01',
#   'death_age': '59',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '347',
#   'birth_date': '1943-05-23',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2021-07-10',
#   'death_age': '78',
#   'visit_date': '2021-02-06',
#   'visit_age': '77',
#   'mmse_tot': '24',
#   'main_complete': '0'},
#  {'patient_id': '365',
#   'birth_date': '',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2006-10-15',
#   'visit_age': '',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '406',
#   'birth_date': '1931-12-18',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-07-24',
#   'visit_age': '91',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '423',
#   'birth_date': '1951-03-03',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-09-29',
#   'visit_age': '71',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '441',
#   'birth_date': '1938-11-20',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2015-04-19',
#   'death_age': '76',
#   'visit_date': '2013-01-03',
#   'visit_age': '74',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '454',
#   'birth_date': '1931-06-22',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-07-22',
#   'visit_age': '77',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '457',
#   'birth_date': '1953-10-25',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-10-22',
#   'visit_age': '59',
#   'mmse_tot': '17',
#   'main_complete': '0'},
#  {'patient_id': '466',
#   'birth_date': '1943-04-09',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-04-15',
#   'visit_age': '67',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '474',
#   'birth_date': '1938-09-28',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2005-08-07',
#   'visit_age': '66',
#   'mmse_tot': '14',
#   'main_complete': '0'},
#  {'patient_id': '476',
#   'birth_date': '1964-04-21',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-04-14',
#   'visit_age': '57',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '484',
#   'birth_date': '1935-09-20',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-11-06',
#   'visit_age': '66',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '491',
#   'birth_date': '1938-03-28',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-11-05',
#   'visit_age': '77',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '494',
#   'birth_date': '1935-05-31',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '2017-05-19',
#   'death_age': '81',
#   'visit_date': '2011-07-11',
#   'visit_age': '76',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '502',
#   'birth_date': '1942-04-17',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2014-04-19',
#   'death_age': '72',
#   'visit_date': '2013-11-28',
#   'visit_age': '71',
#   'mmse_tot': '16',
#   'main_complete': '0'},
#  {'patient_id': '505',
#   'birth_date': '',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-02-19',
#   'visit_age': '',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '516',
#   'birth_date': '1935-05-08',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2003-04-15',
#   'visit_age': '67',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '572',
#   'birth_date': '1933-10-18',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-08-03',
#   'visit_age': '84',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '573',
#   'birth_date': '1942-10-14',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2020-07-13',
#   'visit_age': '77',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '575',
#   'birth_date': '1933-02-13',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-04-11',
#   'visit_age': '90',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '578',
#   'birth_date': '1935-12-26',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-05-03',
#   'visit_age': '66',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '585',
#   'birth_date': '1940-11-20',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '614',
#   'birth_date': '1933-10-14',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2020-10-22',
#   'visit_age': '87',
#   'mmse_tot': '2',
#   'main_complete': '0'},
#  {'patient_id': '616',
#   'birth_date': '1938-09-08',
#   'diagnosis': '5',
#   'sex': '',
#   'handedness': '',
#   'death_date': '2022-04-28',
#   'death_age': '83',
#   'visit_date': '2021-03-29',
#   'visit_age': '82',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '618',
#   'birth_date': '1933-05-20',
#   'diagnosis': '1',
#   'sex': '',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2016-01-07',
#   'visit_age': '82',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '632',
#   'birth_date': '1956-09-21',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-10-30',
#   'visit_age': '61',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '647',
#   'birth_date': '',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-09-29',
#   'visit_age': '',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '651',
#   'birth_date': '1931-05-11',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '22',
#   'main_complete': '0'},
#  {'patient_id': '655',
#   'birth_date': '1953-09-09',
#   'diagnosis': '4',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-10-18',
#   'visit_age': '60',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '669',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-07-05',
#   'visit_age': '',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '673',
#   'birth_date': '1933-01-03',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '690',
#   'birth_date': '1948-09-13',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2000-08-17',
#   'visit_age': '51',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '695',
#   'birth_date': '1946-09-18',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '2023-12-22',
#   'death_age': '77',
#   'visit_date': '2010-01-29',
#   'visit_age': '63',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '698',
#   'birth_date': '1935-04-12',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '5',
#   'main_complete': '0'},
#  {'patient_id': '701',
#   'birth_date': '1935-08-30',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-02-13',
#   'visit_age': '82',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '708',
#   'birth_date': '1930-05-01',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2019-06-27',
#   'visit_age': '89',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '712',
#   'birth_date': '1932-04-10',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-09-01',
#   'visit_age': '70',
#   'mmse_tot': '2',
#   'main_complete': '0'},
#  {'patient_id': '756',
#   'birth_date': '1953-09-21',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2016-02-04',
#   'visit_age': '62',
#   'mmse_tot': '16',
#   'main_complete': '0'},
#  {'patient_id': '758',
#   'birth_date': '1934-01-20',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-08-06',
#   'visit_age': '74',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '773',
#   'birth_date': '1930-02-06',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-02-08',
#   'visit_age': '80',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '777',
#   'birth_date': '1930-08-11',
#   'diagnosis': '2',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '784',
#   'birth_date': '1931-02-20',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-06-08',
#   'visit_age': '84',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '788',
#   'birth_date': '1940-07-25',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-04-21',
#   'visit_age': '69',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '793',
#   'birth_date': '1933-01-13',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-03-14',
#   'visit_age': '68',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '802',
#   'birth_date': '1936-04-10',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-11-03',
#   'visit_age': '65',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '804',
#   'birth_date': '1937-08-14',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2006-02-08',
#   'visit_age': '68',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '820',
#   'birth_date': '',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-07-18',
#   'visit_age': '',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '821',
#   'birth_date': '1932-02-04',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '833',
#   'birth_date': '1951-06-01',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-09-29',
#   'visit_age': '51',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '842',
#   'birth_date': '1935-01-23',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2020-12-19',
#   'visit_age': '85',
#   'mmse_tot': '16',
#   'main_complete': '0'},
#  {'patient_id': '852',
#   'birth_date': '1933-09-04',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '856',
#   'birth_date': '1930-06-08',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2021-08-22',
#   'death_age': '91',
#   'visit_date': '2006-06-16',
#   'visit_age': '76',
#   'mmse_tot': '14',
#   'main_complete': '0'},
#  {'patient_id': '866',
#   'birth_date': '1933-12-10',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-03-20',
#   'visit_age': '68',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '876',
#   'birth_date': '1930-11-16',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-11-08',
#   'visit_age': '78',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '880',
#   'birth_date': '1935-12-28',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '',
#   'death_date': '2023-12-16',
#   'death_age': '87',
#   'visit_date': '2016-01-10',
#   'visit_age': '80',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '883',
#   'birth_date': '1946-06-14',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-05-31',
#   'visit_age': '76',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '886',
#   'birth_date': '1930-08-20',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-09-04',
#   'visit_age': '91',
#   'mmse_tot': '22',
#   'main_complete': '0'},
#  {'patient_id': '896',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-07-12',
#   'visit_age': '',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '920',
#   'birth_date': '1953-05-06',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-02-27',
#   'visit_age': '61',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '923',
#   'birth_date': '1933-11-26',
#   'diagnosis': '3',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-01-01',
#   'visit_age': '75',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '928',
#   'birth_date': '',
#   'diagnosis': '',
#   'sex': '',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-03-10',
#   'visit_age': '',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '933',
#   'birth_date': '1931-03-26',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '949',
#   'birth_date': '1933-08-31',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2016-11-05',
#   'visit_age': '83',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '953',
#   'birth_date': '1941-02-09',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '965',
#   'birth_date': '1933-07-12',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-09-11',
#   'visit_age': '69',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '966',
#   'birth_date': '1934-05-07',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '2016-12-21',
#   'death_age': '82',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '979',
#   'birth_date': '1931-03-09',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '2018-01-18',
#   'death_age': '86',
#   'visit_date': '2014-03-17',
#   'visit_age': '83',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '980',
#   'birth_date': '1937-07-16',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '985',
#   'birth_date': '1957-12-23',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-11-25',
#   'visit_age': '63',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '1003',
#   'birth_date': '1958-07-13',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-02-13',
#   'visit_age': '63',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '1022',
#   'birth_date': '1932-05-15',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-05-18',
#   'visit_age': '70',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1025',
#   'birth_date': '1934-01-13',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2018-06-11',
#   'death_age': '84',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '19',
#   'main_complete': '0'},
#  {'patient_id': '1032',
#   'birth_date': '1939-02-05',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '1043',
#   'birth_date': '1931-06-01',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-01-27',
#   'visit_age': '80',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '1045',
#   'birth_date': '1933-01-08',
#   'diagnosis': '1',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2003-10-24',
#   'visit_age': '70',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '1053',
#   'birth_date': '1930-01-11',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1054',
#   'birth_date': '1942-05-24',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '2021-10-09',
#   'death_age': '79',
#   'visit_date': '2016-06-24',
#   'visit_age': '74',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '1057',
#   'birth_date': '1940-09-10',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-11-10',
#   'visit_age': '70',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '1059',
#   'birth_date': '1938-08-12',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-06-05',
#   'visit_age': '79',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '1060',
#   'birth_date': '1944-08-04',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-05-16',
#   'visit_age': '64',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1070',
#   'birth_date': '1933-02-12',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '1091',
#   'birth_date': '1936-03-12',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2023-01-20',
#   'death_age': '86',
#   'visit_date': '2022-01-09',
#   'visit_age': '85',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '1122',
#   'birth_date': '1932-05-09',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-04-17',
#   'visit_age': '77',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1126',
#   'birth_date': '1932-03-17',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-04-05',
#   'visit_age': '79',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '1137',
#   'birth_date': '1934-03-05',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-02-23',
#   'visit_age': '86',
#   'mmse_tot': '2',
#   'main_complete': '0'},
#  {'patient_id': '1139',
#   'birth_date': '1933-11-15',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-10-25',
#   'visit_age': '83',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1146',
#   'birth_date': '1949-09-07',
#   'diagnosis': '',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-08-31',
#   'visit_age': '71',
#   'mmse_tot': '0',
#   'main_complete': '0'},
#  {'patient_id': '1152',
#   'birth_date': '',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-09-03',
#   'visit_age': '',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '1162',
#   'birth_date': '1934-02-13',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-06-30',
#   'visit_age': '76',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '1165',
#   'birth_date': '1940-12-27',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2016-04-12',
#   'visit_age': '75',
#   'mmse_tot': '5',
#   'main_complete': '0'},
#  {'patient_id': '1169',
#   'birth_date': '1937-09-17',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-10-11',
#   'visit_age': '73',
#   'mmse_tot': '3',
#   'main_complete': '0'},
#  {'patient_id': '1175',
#   'birth_date': '1934-05-15',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2005-08-23',
#   'visit_age': '71',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '1176',
#   'birth_date': '1933-06-25',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-03-27',
#   'visit_age': '87',
#   'mmse_tot': '20',
#   'main_complete': '0'},
#  {'patient_id': '1182',
#   'birth_date': '1930-12-24',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '2015-05-08',
#   'death_age': '84',
#   'visit_date': '2013-02-26',
#   'visit_age': '82',
#   'mmse_tot': '24',
#   'main_complete': '0'},
#  {'patient_id': '1196',
#   'birth_date': '1932-05-05',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-09-29',
#   'visit_age': '72',
#   'mmse_tot': '16',
#   'main_complete': '0'},
#  {'patient_id': '1199',
#   'birth_date': '1953-11-01',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2023-02-05',
#   'visit_age': '69',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '1221',
#   'birth_date': '1938-10-09',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2017-03-17',
#   'death_age': '78',
#   'visit_date': '2016-06-26',
#   'visit_age': '77',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '1224',
#   'birth_date': '1936-04-10',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-08-23',
#   'visit_age': '66',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '1230',
#   'birth_date': '',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-09-02',
#   'visit_age': '',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '1246',
#   'birth_date': '1939-08-01',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '2016-07-12',
#   'death_age': '76',
#   'visit_date': '2002-04-28',
#   'visit_age': '62',
#   'mmse_tot': '16',
#   'main_complete': '0'},
#  {'patient_id': '1248',
#   'birth_date': '1931-11-14',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-05-15',
#   'visit_age': '72',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '1255',
#   'birth_date': '1941-02-10',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2000-01-27',
#   'visit_age': '58',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1256',
#   'birth_date': '1932-08-12',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-12-24',
#   'visit_age': '80',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1309',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2006-12-16',
#   'visit_age': '',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '1318',
#   'birth_date': '',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2007-03-09',
#   'visit_age': '',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '1322',
#   'birth_date': '1932-07-05',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '2019-11-20',
#   'death_age': '87',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '1330',
#   'birth_date': '1932-03-18',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2005-01-02',
#   'visit_age': '72',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '1332',
#   'birth_date': '1947-03-23',
#   'diagnosis': '4',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2007-05-05',
#   'visit_age': '60',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '1343',
#   'birth_date': '1935-06-28',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '1',
#   'main_complete': '0'},
#  {'patient_id': '1348',
#   'birth_date': '1932-05-01',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2014-04-09',
#   'visit_age': '81',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '1349',
#   'birth_date': '1941-08-28',
#   'diagnosis': '5',
#   'sex': '',
#   'handedness': '2',
#   'death_date': '2021-07-25',
#   'death_age': '79',
#   'visit_date': '2009-02-25',
#   'visit_age': '67',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '1364',
#   'birth_date': '1941-12-25',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-01-18',
#   'visit_age': '69',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '1368',
#   'birth_date': '1936-09-22',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '2',
#   'main_complete': '0'},
#  {'patient_id': '1372',
#   'birth_date': '1931-05-19',
#   'diagnosis': '5',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-07-11',
#   'visit_age': '70',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '1384',
#   'birth_date': '1934-08-10',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-05-09',
#   'visit_age': '76',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '1387',
#   'birth_date': '1943-10-25',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-01-28',
#   'visit_age': '65',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '1390',
#   'birth_date': '',
#   'diagnosis': '1',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-03-11',
#   'visit_age': '',
#   'mmse_tot': '14',
#   'main_complete': '0'},
#  {'patient_id': '1402',
#   'birth_date': '1931-04-18',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '1406',
#   'birth_date': '1931-10-17',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2005-03-20',
#   'visit_age': '73',
#   'mmse_tot': '0',
#   'main_complete': '0'},
#  {'patient_id': '1413',
#   'birth_date': '1950-11-14',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-09-12',
#   'visit_age': '51',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1414',
#   'birth_date': '1935-03-06',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2000-10-14',
#   'visit_age': '65',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1419',
#   'birth_date': '1935-01-10',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2020-09-18',
#   'visit_age': '85',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '1424',
#   'birth_date': '1938-01-08',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2012-12-09',
#   'death_age': '74',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '1430',
#   'birth_date': '1951-01-27',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '2022-10-27',
#   'death_age': '71',
#   'visit_date': '2019-04-30',
#   'visit_age': '68',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '1445',
#   'birth_date': '1941-10-11',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-11-27',
#   'visit_age': '77',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '1452',
#   'birth_date': '1931-03-29',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-04-02',
#   'visit_age': '81',
#   'mmse_tot': '30',
#   'main_complete': '0'},
#  {'patient_id': '1463',
#   'birth_date': '1932-01-17',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '',
#   'death_date': '2020-02-22',
#   'death_age': '88',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '1472',
#   'birth_date': '1937-09-30',
#   'diagnosis': '4',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '2014-02-07',
#   'death_age': '76',
#   'visit_date': '2009-02-14',
#   'visit_age': '71',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '1477',
#   'birth_date': '1945-07-11',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-05-02',
#   'visit_age': '76',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '1478',
#   'birth_date': '1934-03-07',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-05-23',
#   'visit_age': '88',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '1480',
#   'birth_date': '',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-04-16',
#   'visit_age': '',
#   'mmse_tot': '1',
#   'main_complete': '0'},
#  {'patient_id': '1520',
#   'birth_date': '',
#   'diagnosis': '2',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '1543',
#   'birth_date': '1936-12-29',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-08-21',
#   'visit_age': '72',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1549',
#   'birth_date': '1962-06-03',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1550',
#   'birth_date': '1933-12-22',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-03-05',
#   'visit_age': '74',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '1566',
#   'birth_date': '',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-03-17',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1570',
#   'birth_date': '1949-04-29',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2006-12-12',
#   'visit_age': '57',
#   'mmse_tot': '30',
#   'main_complete': '0'},
#  {'patient_id': '1572',
#   'birth_date': '1930-01-03',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2019-10-14',
#   'visit_age': '89',
#   'mmse_tot': '22',
#   'main_complete': '0'},
#  {'patient_id': '1574',
#   'birth_date': '1931-03-19',
#   'diagnosis': '4',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-05-03',
#   'visit_age': '87',
#   'mmse_tot': '24',
#   'main_complete': '0'},
#  {'patient_id': '1575',
#   'birth_date': '1932-05-07',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '2018-10-20',
#   'death_age': '86',
#   'visit_date': '2013-09-01',
#   'visit_age': '81',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '1576',
#   'birth_date': '1952-05-02',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '1581',
#   'birth_date': '1932-09-10',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2023-11-14',
#   'death_age': '91',
#   'visit_date': '2023-09-20',
#   'visit_age': '91',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '1583',
#   'birth_date': '1930-04-04',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-03-23',
#   'visit_age': '86',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1586',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-05-06',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1592',
#   'birth_date': '1948-06-20',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-04-30',
#   'visit_age': '60',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '1599',
#   'birth_date': '1939-05-08',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2018-10-12',
#   'visit_age': '79',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '1632',
#   'birth_date': '1932-03-16',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-09-28',
#   'visit_age': '78',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1653',
#   'birth_date': '1930-01-27',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-06-14',
#   'visit_age': '74',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1670',
#   'birth_date': '1932-10-30',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-12-28',
#   'visit_age': '80',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1684',
#   'birth_date': '1957-08-29',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2019-11-12',
#   'visit_age': '62',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '1692',
#   'birth_date': '1934-06-30',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-10-18',
#   'visit_age': '70',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '1697',
#   'birth_date': '1951-10-14',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-05-13',
#   'visit_age': '58',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '1714',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2007-01-13',
#   'visit_age': '',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1718',
#   'birth_date': '1933-04-16',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-09-19',
#   'visit_age': '69',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '1728',
#   'birth_date': '1938-10-27',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2003-12-17',
#   'visit_age': '65',
#   'mmse_tot': '5',
#   'main_complete': '0'},
#  {'patient_id': '1736',
#   'birth_date': '1931-03-11',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '1738',
#   'birth_date': '1945-06-11',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '2020-09-28',
#   'death_age': '75',
#   'visit_date': '2016-04-15',
#   'visit_age': '70',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '1742',
#   'birth_date': '1948-05-10',
#   'diagnosis': '2',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2014-06-28',
#   'visit_age': '66',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '1747',
#   'birth_date': '1933-08-18',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-05-04',
#   'visit_age': '67',
#   'mmse_tot': '9',
#   'main_complete': '0'},
#  {'patient_id': '1761',
#   'birth_date': '1946-11-30',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '2018-05-19',
#   'death_age': '71',
#   'visit_date': '2017-02-08',
#   'visit_age': '70',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '1801',
#   'birth_date': '',
#   'diagnosis': '3',
#   'sex': '',
#   'handedness': '',
#   'death_date': '2024-01-01',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '1807',
#   'birth_date': '1938-08-13',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '1815',
#   'birth_date': '1936-08-05',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-10-04',
#   'visit_age': '85',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '1824',
#   'birth_date': '1934-05-01',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2000-09-02',
#   'visit_age': '66',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '1841',
#   'birth_date': '1933-11-22',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-10-12',
#   'visit_age': '74',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '1860',
#   'birth_date': '1948-03-24',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '2018-12-17',
#   'death_age': '70',
# ...
#   'birth_date': '1931-03-21',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2019-03-03',
#   'visit_age': '87',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '9187',
#   'birth_date': '1936-04-11',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '2019-09-09',
#   'death_age': '83',
#   'visit_date': '2008-09-25',
#   'visit_age': '72',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '9188',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '9193',
#   'birth_date': '1933-09-16',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-09-22',
#   'visit_age': '78',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '9202',
#   'birth_date': '1943-02-16',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2022-09-18',
#   'visit_age': '79',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '9209',
#   'birth_date': '1932-12-14',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-01-29',
#   'visit_age': '71',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '9237',
#   'birth_date': '1931-03-25',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '2020-08-14',
#   'death_age': '89',
#   'visit_date': '2019-11-25',
#   'visit_age': '88',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '9239',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '30',
#   'main_complete': '0'},
#  {'patient_id': '9263',
#   'birth_date': '1937-10-17',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-03-24',
#   'visit_age': '66',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '9274',
#   'birth_date': '1937-02-07',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '2015-07-27',
#   'death_age': '78',
#   'visit_date': '2009-03-21',
#   'visit_age': '72',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '9281',
#   'birth_date': '1930-07-27',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-03-18',
#   'visit_age': '86',
#   'mmse_tot': '0',
#   'main_complete': '0'},
#  {'patient_id': '9293',
#   'birth_date': '1930-12-30',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '2011-10-31',
#   'death_age': '80',
#   'visit_date': '2002-01-17',
#   'visit_age': '71',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9314',
#   'birth_date': '1941-08-19',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-09-29',
#   'visit_age': '67',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '9342',
#   'birth_date': '1931-12-06',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '9351',
#   'birth_date': '1930-03-22',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-03-29',
#   'visit_age': '87',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9368',
#   'birth_date': '1940-05-05',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-09-20',
#   'visit_age': '72',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '9375',
#   'birth_date': '1937-11-29',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2010-03-06',
#   'visit_age': '72',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '9377',
#   'birth_date': '1946-04-22',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2012-10-05',
#   'visit_age': '66',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9408',
#   'birth_date': '1938-03-15',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2008-01-15',
#   'visit_age': '69',
#   'mmse_tot': '23',
#   'main_complete': '0'},
#  {'patient_id': '9410',
#   'birth_date': '1952-05-19',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '0',
#   'main_complete': '0'},
#  {'patient_id': '9420',
#   'birth_date': '1965-07-31',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '2024-01-01',
#   'death_age': '58',
#   'visit_date': '2024-01-01',
#   'visit_age': '58',
#   'mmse_tot': '7',
#   'main_complete': '0'},
#  {'patient_id': '9423',
#   'birth_date': '1949-05-23',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '2022-12-14',
#   'death_age': '73',
#   'visit_date': '2008-04-02',
#   'visit_age': '58',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '9430',
#   'birth_date': '1936-11-15',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2003-08-16',
#   'visit_age': '66',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '9434',
#   'birth_date': '1931-05-06',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-07-04',
#   'visit_age': '78',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '9451',
#   'birth_date': '1939-03-03',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '',
#   'death_date': '2018-11-11',
#   'death_age': '79',
#   'visit_date': '2007-06-08',
#   'visit_age': '68',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '9454',
#   'birth_date': '1930-11-05',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2004-09-12',
#   'visit_age': '73',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9456',
#   'birth_date': '1942-01-30',
#   'diagnosis': '1',
#   'sex': '',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-01-15',
#   'visit_age': '78',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '9462',
#   'birth_date': '1931-12-05',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-10-25',
#   'visit_age': '69',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '9481',
#   'birth_date': '1946-10-21',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-10-02',
#   'visit_age': '74',
#   'mmse_tot': '13',
#   'main_complete': '0'},
#  {'patient_id': '9489',
#   'birth_date': '1932-12-14',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2020-09-22',
#   'visit_age': '87',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '9494',
#   'birth_date': '',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-06-18',
#   'visit_age': '',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '9506',
#   'birth_date': '1930-05-12',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2000-11-30',
#   'visit_age': '70',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9508',
#   'birth_date': '1937-11-12',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '9509',
#   'birth_date': '1942-04-06',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2016-08-24',
#   'visit_age': '74',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '9510',
#   'birth_date': '1938-07-10',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '9526',
#   'birth_date': '1930-07-02',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2006-09-19',
#   'visit_age': '76',
#   'mmse_tot': '0',
#   'main_complete': '0'},
#  {'patient_id': '9543',
#   'birth_date': '1943-02-13',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2003-04-08',
#   'visit_age': '60',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9548',
#   'birth_date': '1951-09-06',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-05-08',
#   'visit_age': '63',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9555',
#   'birth_date': '1930-09-21',
#   'diagnosis': '1',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-07-27',
#   'visit_age': '84',
#   'mmse_tot': '',
#   'main_complete': '0'},
#  {'patient_id': '9558',
#   'birth_date': '1932-10-27',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-10-21',
#   'visit_age': '80',
#   'mmse_tot': '8',
#   'main_complete': '0'},
#  {'patient_id': '9562',
#   'birth_date': '1938-09-14',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2006-10-14',
#   'visit_age': '68',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '9591',
#   'birth_date': '1932-02-15',
#   'diagnosis': '3',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '2016-08-02',
#   'death_age': '84',
#   'visit_date': '2009-08-21',
#   'visit_age': '77',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '9600',
#   'birth_date': '1930-03-09',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2014-08-10',
#   'visit_age': '84',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '9620',
#   'birth_date': '1951-03-11',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2014-10-24',
#   'visit_age': '63',
#   'mmse_tot': '25',
#   'main_complete': '0'},
#  {'patient_id': '9659',
#   'birth_date': '1932-12-02',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '14',
#   'main_complete': '0'},
#  {'patient_id': '9660',
#   'birth_date': '1930-05-24',
#   'diagnosis': '1',
#   'sex': '',
#   'handedness': '2',
#   'death_date': '2022-10-25',
#   'death_age': '92',
#   'visit_date': '2014-09-25',
#   'visit_age': '84',
#   'mmse_tot': '0',
#   'main_complete': '0'},
#  {'patient_id': '9666',
#   'birth_date': '1931-11-20',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '2021-04-13',
#   'death_age': '89',
#   'visit_date': '2020-10-27',
#   'visit_age': '88',
#   'mmse_tot': '11',
#   'main_complete': '0'},
#  {'patient_id': '9672',
#   'birth_date': '1944-04-16',
#   'diagnosis': '4',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2005-03-19',
#   'visit_age': '60',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9679',
#   'birth_date': '1931-03-21',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-11-10',
#   'visit_age': '80',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '9683',
#   'birth_date': '1931-01-30',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '2012-04-14',
#   'death_age': '81',
#   'visit_date': '2007-01-29',
#   'visit_age': '75',
#   'mmse_tot': '0',
#   'main_complete': '0'},
#  {'patient_id': '9689',
#   'birth_date': '1930-06-22',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2019-04-19',
#   'visit_age': '88',
#   'mmse_tot': '1',
#   'main_complete': '0'},
#  {'patient_id': '9694',
#   'birth_date': '1940-02-05',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2002-11-08',
#   'visit_age': '62',
#   'mmse_tot': '26',
#   'main_complete': '0'},
#  {'patient_id': '9700',
#   'birth_date': '1948-08-31',
#   'diagnosis': '4',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2016-06-21',
#   'visit_age': '67',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '9709',
#   'birth_date': '1930-11-13',
#   'diagnosis': '',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '9724',
#   'birth_date': '1951-02-25',
#   'diagnosis': '',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2017-02-21',
#   'visit_age': '65',
#   'mmse_tot': '24',
#   'main_complete': '0'},
#  {'patient_id': '9731',
#   'birth_date': '1931-06-13',
#   'diagnosis': '5',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2014-03-12',
#   'visit_age': '82',
#   'mmse_tot': '28',
#   'main_complete': '0'},
#  {'patient_id': '9732',
#   'birth_date': '1950-01-21',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2001-12-07',
#   'visit_age': '51',
#   'mmse_tot': '29',
#   'main_complete': '0'},
#  {'patient_id': '9753',
#   'birth_date': '',
#   'diagnosis': '2',
#   'sex': '1',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2015-07-21',
#   'visit_age': '',
#   'mmse_tot': '18',
#   'main_complete': '0'},
#  {'patient_id': '9763',
#   'birth_date': '',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '1',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2009-04-06',
#   'visit_age': '',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '9783',
#   'birth_date': '1930-01-22',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2021-11-15',
#   'visit_age': '91',
#   'mmse_tot': '10',
#   'main_complete': '0'},
#  {'patient_id': '9789',
#   'birth_date': '1942-06-01',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2013-10-17',
#   'visit_age': '71',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '9790',
#   'birth_date': '',
#   'diagnosis': '2',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2011-02-03',
#   'visit_age': '',
#   'mmse_tot': '4',
#   'main_complete': '0'},
#  {'patient_id': '9801',
#   'birth_date': '1937-06-10',
#   'diagnosis': '5',
#   'sex': '1',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2003-12-09',
#   'visit_age': '66',
#   'mmse_tot': '27',
#   'main_complete': '0'},
#  {'patient_id': '9804',
#   'birth_date': '1937-06-17',
#   'diagnosis': '3',
#   'sex': '2',
#   'handedness': '2',
#   'death_date': '2018-10-16',
#   'death_age': '81',
#   'visit_date': '2012-10-08',
#   'visit_age': '75',
#   'mmse_tot': '12',
#   'main_complete': '0'},
#  {'patient_id': '9814',
#   'birth_date': '',
#   'diagnosis': '1',
#   'sex': '2',
#   'handedness': '',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '2005-10-28',
#   'visit_age': '',
#   'mmse_tot': '6',
#   'main_complete': '0'},
#  {'patient_id': '9830',
#   'birth_date': '1933-03-01',
#   'diagnosis': '4',
#   'sex': '',
#   'handedness': '3',
#   'death_date': '',
#   'death_age': '',
#   'visit_date': '',
#   'visit_age': '',
#   'mmse_tot': '24',
#   'main_complete': '0'},
#  ...]

# %%
# Convert the output to a pandas DataFrame
import pandas as pd

df_redcap = pd.DataFrame(redcap_data)
df_redcap.head()

display(df_redcap.head())

# NOTE: You can also just export as a pandas DataFrame directly like this:
# redcap_data = redcap_project.export_records(format='df')
# Out:
#   patient_id  birth_date diagnosis sex handedness death_date death_age  \
# 0         23  1941-02-14         2   2          1
# 1         53  1930-04-12         1   2          3
# 2         70  1942-04-26         1   1          3
# 3         87  1933-05-09         4   1          3
# 4         97  1945-02-12         2   2          2
#
#    visit_date visit_age mmse_tot main_complete
# 0  2011-11-29        70                      0
# 1  2012-01-25        81        6             0
# 2                             12             0
# 3  2022-12-22        89       18             0
# 4  2017-10-31        72        9             0

# %% [markdown]
# ### Example 1:
# - Dr. X wants to know how many patients in the database have a diagnosis of Alzheimer's Disease (AD).
#     - Of those cases, how many were under/over 70 years old at testing?

# %%
# The variable/column name we are looking for first is "diagnosis" and the value for Alzheimer's Disease is 1
# Now, let's filter the dataframe to only cases with Alzheimer's Disease
df_ad = df_redcap[df_redcap['diagnosis'] == "1"]

# Print the total number of AD cases:
print(f"Total number of AD cases: {len(df_ad)}")
# Out:
# Total number of AD cases: 2246

# %%
# Now let's split the group into two groups based on the age cut off of 70 in the variable "visit_age"
age_cutoff = "70"
df_ad_young = df_ad[df_ad['visit_age'] < age_cutoff]
df_ad_old = df_ad[df_ad['visit_age'] >= age_cutoff]

# Print how many cases are in each group
print(f"Number of Alzheimer's Disease cases under {age_cutoff} years old: {len(df_ad_young)}")
print(f"Number of Alzheimer's Disease cases over {age_cutoff} years old: {len(df_ad_old)}")
# Out:
# Number of Alzheimer's Disease cases under 70 years old: 1064
# Number of Alzheimer's Disease cases over 70 years old: 1182

# %% [markdown]
# ### Example 2:
# - Dr. X now wants to know the amounts of all diagnoses but displayed in a nice, labeled pie chart.

# %%
# Let's take the original data and create a pie chart of the distribution of the different diagnoses
import matplotlib.pyplot as plt

# Plot the distribution of the different diagnoses
plt.figure(figsize=(4, 4), dpi=100)
df_redcap['diagnosis'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Diagnoses')
plt.show()

# %%
# That's nice, but the number values aren't very informative and the NaN values are not labeled.
# Let's try replacing the values with labels using the data dictionary / metadata.

# You can extract the metadata of the project using PyCap like this:
metadata = redcap_project.export_metadata(format_type='df')
# Reset the index of the header rows:
metadata = metadata.groupby('field_name').first().reset_index()
metadata
# Out:
#    field_name form_name  section_header field_type        field_label  \
# 0  birth_date      main             NaN       text               DOB:
# 1   death_age      main             NaN       calc       Age at Death
# 2  death_date      main             NaN       text      Date of Death
# 3   diagnosis      main             NaN   dropdown         Diagnosis:
# 4  handedness      main             NaN   dropdown         Handedness
# 5    mmse_tot      main             NaN       text   MMSE Total Score
# 6  patient_id      main             NaN       text  Patient ID Number
# 7         sex      main             NaN   dropdown                Sex
# 8   visit_age      main             NaN       calc       Age at Visit
# 9  visit_date      main             NaN       text      Date of Visit
#
#                       select_choices_or_calculations  field_note  \
# 0                                               None         NaN
# 1  rounddown(datediff([birth_date], [death_date],...         NaN
# 2                                               None         NaN
# 3  1, Alzheimer's Disease | 2, Frontotemporal Dem...         NaN
# 4               1, Right | 2, Left | 3, Ambidextrous         NaN
# 5                                               None         NaN
# 6                                               None         NaN
# 7                                1, Male | 2, Female         NaN
# 8  rounddown(datediff([birth_date], [visit_date],...         NaN
# 9                                               None         NaN
#
#   text_validation_type_or_show_slider_number  text_validation_min  \
# 0                                   date_mdy                  NaN
# 1                                       None                  NaN
# 2                                   date_mdy                  NaN
# 3                                       None                  NaN
# 4                                       None                  NaN
# 5                                    integer                  0.0
# 6                                       None                  NaN
# 7                                       None                  NaN
# 8                                       None                  NaN
# 9                                   date_mdy                  NaN
#
#    text_validation_max identifier  branching_logic  required_field  \
# 0                  NaN          y              NaN             NaN
# 1                  NaN          y              NaN             NaN
# 2                  NaN          y              NaN             NaN
# 3                  NaN       None              NaN             NaN
# 4                  NaN       None              NaN             NaN
# 5                 30.0       None              NaN             NaN
# 6                  NaN       None              NaN             NaN
# 7                  NaN       None              NaN             NaN
# 8                  NaN       None              NaN             NaN
# 9                  NaN       None              NaN             NaN
#
#    custom_alignment  question_number  matrix_group_name  matrix_ranking  \
# 0               NaN              NaN                NaN             NaN
# 1               NaN              NaN                NaN             NaN
# 2               NaN              NaN                NaN             NaN
# 3               NaN              NaN                NaN             NaN
# 4               NaN              NaN                NaN             NaN
# 5               NaN              NaN                NaN             NaN
# 6               NaN              NaN                NaN             NaN
# 7               NaN              NaN                NaN             NaN
# 8               NaN              NaN                NaN             NaN
# 9               NaN              NaN                NaN             NaN
#
#    field_annotation
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN

# %%
# First, let's extract the choices for the "diagnosis" variable from the metadata df 
# by finding the 'field_name' key with the value 'diagnosis' and then returning the 'select_choices_or_calculations' key:
# Return the value for the 'select_choices_or_calculations' key
diagnosis_choices = metadata[metadata['field_name'] == 'diagnosis']['select_choices_or_calculations'].values[0]
# Make the choices into a dict:
diagnosis_choices_dict = dict(item.split(", ") for item in diagnosis_choices.split(" | "))
diagnosis_choices_dict
# Out:
# {'1': "Alzheimer's Disease",
#  '2': 'Frontotemporal Dementia',
#  '3': 'Primary Progressive Aphasia',
#  '4': 'Mild Cognitive Impairment',
#  '5': 'Control'}

# %%
# Great! Now that we have the relabel dict, we can use it to replace the values in the 'diagnosis' column
# with the actual labels in the plot. But! We still haven't handled the blank/NaN values.
# Let's add to the relable dict a key for the blank/NaN values and call them "Unknown"
diagnosis_choices_dict[''] = 'Unknown'
diagnosis_choices_dict
# Out:
# {'1': "Alzheimer's Disease",
#  '2': 'Frontotemporal Dementia',
#  '3': 'Primary Progressive Aphasia',
#  '4': 'Mild Cognitive Impairment',
#  '5': 'Control',
#  '': 'Unknown'}

# %%
# Now, let's plot the distribution of the diagnoses again but relabeled:
plt.figure(figsize=(4, 4), dpi=100)
df_redcap['diagnosis'].replace(diagnosis_choices_dict).value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('') # Remove the "count" label
plt.title('Diagnoses')
plt.show()

# %% [markdown]
# ### Example 3:
# - Dr. X now wants this kind of pie chart for every other categorical variable too (e.g. Sex, Handedness, etc.)

# %%
# Rather than doing this all manually every time, let's semi-automate this
# by creating a function to make pie charts for all categorical variables in the data.

def categorical_pie(df, metadata):
    # Find every categorical variable in the metadata (e.g. 'radio', 'dropdown')
    categorical_vars = metadata[metadata['field_type'].str.contains('dropdown|radio', case=False)]
    # Get the field_name, field_label, and selected choices for each categorical variable
    for index, row in categorical_vars.iterrows():
        field_name = row['field_name']
        field_label = row['field_label']
        choices = dict(item.split(", ") for item in row['select_choices_or_calculations'].split(" | "))
        # Add the "Unknown" label for blank/NaN values:
        choices[''] = 'Unknown'
        # Plot the pie chart
        plt.figure(figsize=(4, 4), dpi=100)
        df[field_name].replace(choices).value_counts().plot.pie(autopct='%1.1f%%')
        plt.ylabel('')
        plt.title(field_label)

categorical_pie(df_redcap, metadata)

# %% [markdown]
# ### More complicated example:
# - Dr. X has an important grant submission coming up and needs the following:
#     - A table with Sex, Handedness, Age at Visit, and MMSE by Diagnosis
#     - Also, plot the MMSE scores by diagnosis.

# %%
# Here is a function that generates a table of demographics for a given group variable
# with categorical and continuous variable lists, replaces the variable names and values with labels,
# adds percentages and counts for categorical variables, and means and standard deviations for continuous variables.

import numpy as np

def create_demographics_table(df, metadata, group_var, categorical_vars, continuous_vars):
    """
    Create a demographics table displaying mean ± SD (n=...) for continuous variables and
    percentages (n=...) for categorical variables, grouped by a specified variable.
    Variable names and codes are replaced with their labels from the metadata.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame containing the dataset.
    metadata (pd.DataFrame): The REDCap metadata DataFrame.
    group_var (str): The name of the grouping variable.
    categorical_vars (list): A list of names of the categorical variables.
    continuous_vars (list): A list of names of the continuous variables.
    
    Returns:
    pd.DataFrame: A formatted demographics table.
    """
    # Create a deep copy of the DataFrame to prevent in-place modifications
    df = df.copy(deep=True)
    
    # Create a mapping from field_name to field_label
    field_label_mapping = dict(zip(metadata['field_name'], metadata['field_label']))
    
    # Replace variable names with their labels
    group_var_label = field_label_mapping.get(group_var, group_var)
    continuous_vars_labels = [field_label_mapping.get(var, var) for var in continuous_vars]
    categorical_vars_labels = [field_label_mapping.get(var, var) for var in categorical_vars]    
    
    # Replace codes with labels in the grouping variable if it's categorical
    group_var_field_type = metadata.loc[metadata['field_name'] == group_var, 'field_type'].values
    if len(group_var_field_type) > 0 and group_var_field_type[0] in ['dropdown', 'radio']:
        choices_str = metadata.loc[metadata['field_name'] == group_var, 'select_choices_or_calculations'].values[0]
        choices_dict = dict(item.strip().split(', ', 1) for item in choices_str.split(' | '))
        # Include "" as a category labeled "Unknown"
        choices_dict[''] = 'Unknown'
        df[group_var] = df[group_var].astype(str).replace({'nan': ''}).map(choices_dict).fillna('Unknown')
    else:
        # For non-dropdown/radio fields, treat NaN as "Unknown"
        df[group_var] = df[group_var].astype(str).replace({'nan': ''}).fillna('Unknown')
    
    # Process categorical variables to replace codes with labels
    for var in categorical_vars:
        field_type = metadata.loc[metadata['field_name'] == var, 'field_type'].values
        if len(field_type) > 0 and field_type[0] in ['dropdown', 'radio']:
            choices_str = metadata.loc[metadata['field_name'] == var, 'select_choices_or_calculations'].values[0]
            choices_dict = dict(item.strip().split(', ', 1) for item in choices_str.split(' | '))
            # Include "" as a category labeled "Unknown"
            choices_dict[''] = 'Unknown'
            df[var] = df[var].astype(str).replace({'nan': ''}).map(choices_dict).fillna('Unknown')
        else:
            # For non-dropdown/radio fields, treat NaN as "Unknown"
            df[var] = df[var].astype(str).replace({'nan': ''}).fillna('Unknown')
    
    # Ensure continuous variables are numeric
    for var in continuous_vars:
        df[var] = pd.to_numeric(df[var], errors='coerce')
    
    # Initialize an empty list to collect results
    results = []
    
    # Get unique groups, including 'Unknown' for missing values
    groups = df[group_var].unique()
    
    # Process continuous variables
    for i, var in enumerate(continuous_vars):
        var_label = continuous_vars_labels[i]
        # Group by the group variable and calculate mean, standard deviation, and count
        grouped = df.groupby(group_var)[var].agg(['mean', 'std', 'count'])
        for grp in groups:
            mean = grouped.loc[grp, 'mean']
            std = grouped.loc[grp, 'std']
            count = int(grouped.loc[grp, 'count'])
            if pd.isnull(mean) or pd.isnull(std):
                value = "NaN"
            else:
                value = f"{mean:.2f} ± {std:.2f} (n={count})"
            results.append({
                'Variable': var_label,
                'Group': grp,
                'Value': value
            })
    
    # Process categorical variables
    for i, var in enumerate(categorical_vars):
        var_label = categorical_vars_labels[i]
        categories = df[var].dropna().unique()
        # Ensure "Unknown" is included in categories if any missing values
        if 'Unknown' in df[var].values and 'Unknown' not in categories:
            categories = np.append(categories, 'Unknown')
        for category in categories:
            for grp in groups:
                grp_data = df[df[group_var] == grp]
                total_count = len(grp_data)
                if total_count == 0:
                    pct = 0
                    n = 0
                else:
                    count = grp_data[var].value_counts().get(category, 0)
                    pct = (count / total_count) * 100
                    n = count
                # Replace empty category labels with "Unknown"
                category_label = category if category != '' else 'Unknown'
                results.append({
                    'Variable': f"{var_label} ({category_label})",
                    'Group': grp,
                    'Value': f"{pct:.1f}% (n={n})"
                })
    
    # Convert results to DataFrame
    result_df = pd.DataFrame(results)
    
    # Pivot the table to have groups as columns
    table = result_df.pivot(index='Variable', columns='Group', values='Value')
    
    # Optional: Reorder the index to display continuous variables first
    variable_order = continuous_vars_labels + [
        f"{field_label_mapping.get(var, var)} ({cat if cat != '' else 'Unknown'})"
        for var, var_label in zip(categorical_vars, categorical_vars_labels)
        for cat in df[var].dropna().unique()
    ]
    table = table.reindex(variable_order)
    
    # Reset index for better display
    table = table.reset_index()
    
    # Rename the 'Group' columns to include the group variable label
    table.columns.name = group_var_label
    
    return table

# %%
# Specify variables/columns:
group_var = 'diagnosis'
categorical_vars = ['sex', 'handedness']
continuous_vars = ['visit_age', 'mmse_tot']

# Create the demographics table
demographics_table = create_demographics_table(df_redcap, metadata, group_var, categorical_vars, continuous_vars)
display(demographics_table)
# Out:
# Diagnosis:                   Variable    Alzheimer's Disease  \
# 0                        Age at Visit  73.86 ± 8.48 (n=1819)
# 1                    MMSE Total Score   5.70 ± 3.90 (n=2031)
# 2                        Sex (Female)         44.7% (n=1004)
# 3                          Sex (Male)         45.1% (n=1012)
# 4                       Sex (Unknown)          10.2% (n=230)
# 5                  Handedness (Right)          30.5% (n=684)
# 6           Handedness (Ambidextrous)          28.5% (n=640)
# 7                   Handedness (Left)          30.8% (n=692)
# 8                Handedness (Unknown)          10.2% (n=230)
#
# Diagnosis:                 Control Frontotemporal Dementia  \
# 0           72.97 ± 10.05 (n=2169)   74.22 ± 8.65 (n=1116)
# 1            27.85 ± 1.14 (n=2414)    8.20 ± 4.06 (n=1260)
# 2                   42.9% (n=1152)           46.8% (n=649)
# 3                   47.9% (n=1286)           43.3% (n=601)
# 4                     9.3% (n=249)            9.9% (n=137)
# 5                    29.8% (n=802)           29.1% (n=404)
# 6                    30.0% (n=805)           28.9% (n=401)
# 7                    30.5% (n=820)           32.1% (n=445)
# 8                     9.7% (n=260)            9.9% (n=137)
#
# Diagnosis: Mild Cognitive Impairment Primary Progressive Aphasia  \
# 0              72.84 ± 9.90 (n=1092)       73.58 ± 8.36 (n=1078)
# 1              24.28 ± 1.87 (n=1223)       11.63 ± 4.09 (n=1217)
# 2                      45.1% (n=615)               45.3% (n=605)
# 3                      44.0% (n=600)               43.5% (n=581)
# 4                      10.9% (n=148)               11.2% (n=149)
# 5                      31.8% (n=434)               29.4% (n=392)
# 6                      27.6% (n=376)               28.8% (n=385)
# 7                      29.6% (n=404)               31.8% (n=425)
# 8                      10.9% (n=149)               10.0% (n=133)
#
# Diagnosis:                Unknown
# 0            73.69 ± 9.12 (n=799)
# 1           16.15 ± 10.09 (n=893)
# 2                   45.6% (n=448)
# 3                   44.0% (n=432)
# 4                   10.4% (n=102)
# 5                   28.5% (n=280)
# 6                   32.6% (n=320)
# 7                   27.2% (n=267)
# 8                   11.7% (n=115)

# %%
# Now to make the plot, we will go ahead and make a reusable plotting function also
# so that we can use it for other comparisons in the future as well.

import seaborn as sns

def plot_continuous_variable_by_group(df, metadata, continuous_var, group_var, bins=None):
    """
    Plots a histogram of a continuous variable grouped by a categorical variable with side-by-side bars.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame containing the dataset.
    metadata (pd.DataFrame): The REDCap metadata DataFrame.
    continuous_var (str): The name of the continuous variable in the DataFrame.
    group_var (str): The name of the grouping variable in the DataFrame.
    bins (int or sequence): Number of bins or bin edges for the histogram.
    
    Returns:
    None: Displays the histogram plot.
    """
    # Create a copy of the DataFrame to prevent in-place modifications
    df = df.copy(deep=True)
    
    # Map codes to labels for the grouping variable using metadata
    # Get the field_label for the grouping variable
    group_var_label = metadata.loc[metadata['field_name'] == group_var, 'field_label'].values
    if len(group_var_label) > 0:
        group_var_label = group_var_label[0]
    else:
        group_var_label = group_var
    
    # Map codes to labels for the grouping variable
    group_var_field_type = metadata.loc[metadata['field_name'] == group_var, 'field_type'].values
    if len(group_var_field_type) > 0 and group_var_field_type[0] in ['dropdown', 'radio']:
        choices_str = metadata.loc[metadata['field_name'] == group_var, 'select_choices_or_calculations'].values[0]
        choices_dict = dict(item.strip().split(', ', 1) for item in choices_str.split(' | '))
        # Include "" as a category labeled "Unknown"
        choices_dict[''] = 'Unknown'
        df[group_var] = df[group_var].astype(str).replace({'nan': ''}).map(choices_dict).fillna('Unknown')
    else:
        df[group_var] = df[group_var].astype(str).replace({'nan': ''}).fillna('Unknown')
    
    # Map codes to labels for the continuous variable if necessary
    continuous_var_label = metadata.loc[metadata['field_name'] == continuous_var, 'field_label'].values
    if len(continuous_var_label) > 0:
        continuous_var_label = continuous_var_label[0]
    else:
        continuous_var_label = continuous_var
    
    # Ensure continuous variable is numeric
    df[continuous_var] = pd.to_numeric(df[continuous_var], errors='coerce')
    
    # Drop rows with NaN in continuous variable
    df = df.dropna(subset=[continuous_var])
    
    # Define bins if not provided
    if bins is None:
        bins = range(int(df[continuous_var].min()), int(df[continuous_var].max()) + 2)  # +2 to include max value
    
    # Create a pivot table to get counts per bin per group
    df['bin'] = pd.cut(df[continuous_var], bins=bins, right=False, include_lowest=True)
    pivot_table = df.pivot_table(index='bin', columns=group_var, values=continuous_var, aggfunc='count', fill_value=0, observed=False)
    
    # Prepare data for plotting
    bin_labels = [f"{int(interval.left)}" for interval in pivot_table.index]
    groups = pivot_table.columns.tolist()
    counts = pivot_table.values
    
    # Plotting
    x = np.arange(len(bin_labels))  # the label locations
    total_width = 0.8
    num_groups = len(groups)
    width = total_width / num_groups  # the width of the bars
    
    fig, ax = plt.subplots(figsize=(12, 6))
    
    # Generate color palette
    colors = sns.color_palette('Set2', num_groups)
    
    # Plot each group's bars
    for i, group in enumerate(groups):
        ax.bar(x + i * width - total_width / 2, counts[:, i], width, label=str(group), color=colors[i])
    
    # Set labels and titles
    ax.set_xlabel(continuous_var_label)
    ax.set_ylabel('Frequency')
    ax.set_title(f'Distribution of {continuous_var_label} by {group_var_label}')
    ax.set_xticks(x)
    ax.set_xticklabels(bin_labels)
    ax.legend(title=group_var_label)
    
    plt.tight_layout()
    plt.show()

# %%
# Plot the MMSE scores by Diagnoses
plot_continuous_variable_by_group(df_redcap, metadata, continuous_var='mmse_tot', group_var='diagnosis')

# %%
# Clearly the controls have higher MMSE scores (by definition) than the dementia cases, 
# so let's rerun the graph on a subset without the controls or "unknown" diagnoses for clarity:
df_mmse_trim = df_redcap[(df_redcap['diagnosis'] != '5') & (df_redcap['diagnosis'] != '')]

# Plot the MMSE scores by Diagnoses
plot_continuous_variable_by_group(df_mmse_trim, metadata, continuous_var='mmse_tot', group_var='diagnosis')

# %%
# Since we made a reusable function, we can also use it to plot other continuous variables by group.
# Like Age vs Sex (with the unknowns removed):
df_sex_trim = df_redcap[(df_redcap['sex'] != '')]

plot_continuous_variable_by_group(df_sex_trim, metadata, 'visit_age', 'sex', bins=15)
